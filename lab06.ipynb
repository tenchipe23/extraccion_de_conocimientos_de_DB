# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv("dataset_sucio_practica.csv")

# %%
df.shape
# Out:
# (125, 8)

# %%
df.head()
# Out:
#    id          nombre   edad                 correo       pais  salario  \
# 0   1     Julia Zhang  150.0       aortiz@perry.com        NaN  25000.0
# 1   2             NaN   35.0     asimmons@garza.com     España      NaN
# 2   3    George Burke   40.0  mcclainerin@gmail.com  Argentina      NaN
# 3   4  Joyce Williams   30.0        correo_invalido  Argentina  25000.0
# 4   5  Elaine Sanchez   -5.0        correo_invalido     México  25000.0
#
#   fecha_registro activo
# 0     2026-03-09     Sí
# 1     2026-05-04     No
# 2     2026-01-27    NaN
# 3     2025-02-23     No
# 4     2025-03-28     Sí

# %%
df.tail()
# Out:
#      id          nombre   edad                 correo       pais  salario  \
# 120   1     Julia Zhang  150.0       aortiz@perry.com        NaN  25000.0
# 121   2             NaN   35.0     asimmons@garza.com     España      NaN
# 122   3    George Burke   40.0  mcclainerin@gmail.com  Argentina      NaN
# 123   4  Joyce Williams   30.0        correo_invalido  Argentina  25000.0
# 124   5  Elaine Sanchez   -5.0        correo_invalido     México  25000.0
#
#     fecha_registro activo
# 120     2026-03-09     Sí
# 121     2026-05-04     No
# 122     2026-01-27    NaN
# 123     2025-02-23     No
# 124     2025-03-28     Sí

# %%
df.describe()
# Out:
#                id        edad       salario
# count  125.000000  110.000000    107.000000
# mean    58.200000   43.945455  14093.457944
# std     35.906465   47.489803   8825.918852
# min      1.000000   -5.000000  -1000.000000
# 25%     27.000000   22.750000  12000.000000
# 50%     58.000000   30.000000  15000.000000
# 75%     89.000000   40.000000  18000.000000
# max    120.000000  150.000000  25000.000000

# %%
dfCopy = df.copy()
dfCopy.shape
# Out:
# (125, 8)

# %%
df[df["id"].isin([29,55,58])]
# Out:
#     id           nombre  edad                    correo    pais  salario  \
# 28  29     Teresa Ramos  22.0  rileyraymond@hotmail.com  México  -1000.0
# 54  55       John Lewis   NaN  rodriguezbrett@yahoo.com  México  -1000.0
# 57  58  Michael Barajas  40.0    antoniocox@hotmail.com  España  15000.0
#
#    fecha_registro activo
# 28     2025-08-29    NaN
# 54     2024-07-03    NaN
# 57     2026-05-02    NaN

# %%
plt.figure(figsize = (12,6))
sns.heatmap(df.isnull(), cbar = False)
plt.title("mapa de valores nulos")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %%
df.drop_duplicates(inplace = True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[(df["edad"]< 0 ) | (df["edad"] > 110) ]
# Out:
#       id              nombre   edad                                 correo  \
# 0      1         Julia Zhang  150.0                       aortiz@perry.com
# 4      5      Elaine Sanchez   -5.0                        correo_invalido
# 6      7       Roberto Smith   -5.0                     vegasara@yahoo.com
# 7      8     Nicholas Torres   -5.0                   arnoldjoe@macias.biz
# 9     10     Angela Richards   -5.0               rubiogabrielle@yahoo.com
# 12    13            Paul Liu  150.0                        ilong@gmail.com
# 16    17   Christopher Klein   -5.0                  ericarice@hotmail.com
# 22    23   Mrs. Diane Carter  150.0               schultzpatrick@mccoy.net
# 23    24          Vicki Love   -5.0                  antonio14@johnson.net
# 24    25      Matthew Porter   -5.0                hansoncameron@yahoo.com
# 38    39       Rose Williams   -5.0                     jesus70@berger.org
# ...

# %%
df.loc[(df["edad"]< 0 ) | (df["edad"] > 110), "edad"] = np.nan

# %%
df[(df["edad"]< 0 ) | (df["edad"] > 110) ]
# Out:
# Empty DataFrame
# Columns: [id, nombre, edad, correo, pais, salario, fecha_registro, activo]
# Index: []

# %%
mediana_edad = df ["edad"].median()
mediana_edad
# Out:
# 30.0

# %%
df["edad"] = df["edad"].fillna(mediana_edad)

# %%
df["edad"].describe()
# Out:
# count    120.000000
# mean      30.325000
# std        4.745918
# min       22.000000
# 25%       30.000000
# 50%       30.000000
# 75%       31.250000
# max       40.000000
# Name: edad, dtype: float64

# %%
df[df["salario"] < 0]
# Out:
#       id              nombre  edad                                 correo  \
# 9     10     Angela Richards  30.0               rubiogabrielle@yahoo.com
# 11    12       Daniel Wright  25.0               melissamaxwell@gmail.com
# 20    21     Marc Miller DDS  30.0          ccalderon@campbell-carter.com
# 21    22     Carrie Griffith  30.0                        correo_invalido
# 26    27        Mary Miranda  40.0                  brendaglenn@gmail.com
# 27    28         John Taylor  30.0                jonesashley@hotmail.com
# 28    29        Teresa Ramos  22.0               rileyraymond@hotmail.com
# 37    38       Brian Sherman  30.0                    brianna61@yahoo.com
# 41    42   Patricia Morrison  30.0                       uweiss@yahoo.com
# 44    45        John Estrada  35.0                  nichole26@hotmail.com
# 45    46       Jeremy Cooper  35.0                 vfrederick@hotmail.com
# 48    49        Willie Marks  30.0                   joshua86@farrell.com
# ...

# %%
df.loc[(df["salario"] < 0), "salario"] = np.nan 
df[df["salario"] < 0]
# Out:
# Empty DataFrame
# Columns: [id, nombre, edad, correo, pais, salario, fecha_registro, activo]
# Index: []

# %%
mediana_salario = df ["salario"].median()
mediana_salario
# Out:
# 15000.0

# %%
df["salario"] = df["salario"].fillna(mediana_salario)
df["salario"].describe()
# Out:
# count      120.000000
# mean     16741.666667
# std       4401.099621
# min      12000.000000
# 25%      15000.000000
# 50%      15000.000000
# 75%      18000.000000
# max      25000.000000
# Name: salario, dtype: float64

# %%
 df[~df["correo"].str.contains("@",na = False)]
# Out:
#     id             nombre  edad correo       pais  salario fecha_registro  \
# 3    4     Joyce Williams  30.0   <NA>  Argentina  25000.0     2025-02-23
# 4    5     Elaine Sanchez  30.0   <NA>     México  25000.0     2025-03-28
# 18  19     Nicholas Curry  35.0   <NA>     México  12000.0     2025-11-22
# 21  22    Carrie Griffith  30.0   <NA>        NaN  15000.0     2025-05-05
# 30  31  Mrs. Sara Johnson  35.0   <NA>  Argentina  15000.0     2026-03-07
# 40  41     Cynthia Arnold  30.0   <NA>        NaN  25000.0     2024-11-03
# 65  66      Michael Lopez  40.0   <NA>     España  15000.0     2025-12-01
# 78  79       Charles Page  25.0   <NA>        NaN  15000.0     2025-09-01
# 87  88                NaN  22.0   <NA>        NaN  12000.0     2025-03-07
# 88  89      Erika Bernard  30.0   <NA>  Argentina  12000.0     2024-11-16
# 94  95        Daniel Wong  30.0   <NA>     España  15000.0     2026-04-29
# 95  96         Luis Drake  25.0   <NA>        NaN  25000.0     2025-01-22
#
# ...

# %%
correo_invalido = ~df["correo"].str.contains("@",na = False)
df.loc[correo_invalido, "correo"] = pd.NA

# %%
 df["pais"].isnull().sum()
# Out:
# np.int64(0)

# %%
moda_pais = df["pais"].mode()[0]
moda_pais
# Out:
# 'Argentina'

# %%
df["pais"] = df["pais"].fillna(moda_pais)

# %%
df.dtypes
# Out:
# id                  int64
# nombre             object
# edad              float64
# correo             object
# pais               object
# salario           float64
# fecha_registro     object
# activo             object
# dtype: object

# %%
df["fecha_registro"] = pd.to_datetime(df["fecha_registro"])
df.dtypes
# Out:
# id                         int64
# nombre                    object
# edad                     float64
# correo                    object
# pais                      object
# salario                  float64
# fecha_registro    datetime64[ns]
# activo                    object
# dtype: object

# %%
df["fecha_registro"].dt.year
# Out:
# 0      2026
# 1      2026
# 2      2026
# 3      2025
# 4      2025
#        ...
# 115    2024
# 116    2024
# 117    2026
# 118    2025
# 119    2026
# Name: fecha_registro, Length: 120, dtype: int32

# %%
df["activo"].value_countsf(dropna = False)
# Out:
# activo
# Sí     47
# No     39
# NaN    34
# Name: count, dtype: int64

# %%
df["activo"] = df["activo"].fillna("Sí")
df["activo"].value_counts(dropna = False)
# Out:
# activo
# Sí    81
# No    39
# Name: count, dtype: int64

# %%
df["activo"] = df["activo"].map({
    "Sí":1,
    "No":0
})
df["activo"].value_counts(dropna = False)
# Out:
# activo
# 1    81
# 0    39
# Name: count, dtype: int64

# %%
(df.isnull().sum() / len(df) * 100)
# Out:
# id                 0.000000
# nombre             6.666667
# edad               0.000000
# correo            10.000000
# pais               0.000000
# salario            0.000000
# fecha_registro     0.000000
# activo             0.000000
# dtype: float64

# %% [markdown]
# # CONCLUSIONES
# - durante la practica se identificaron y corrigieron los siguientes probleas:
# 1. borrar los datos dublicados
# 2. corregir datos invalidos y atipicos
# 3. realizar y corregir tipos de da
